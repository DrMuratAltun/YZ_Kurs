# %% [markdown]
# ![image.png](attachment:4f4b3924-22a8-40cd-a123-76b2caef7881.png)

# %% [markdown]
# # Veri Görselleştirme
# * **Veri Görselleştirme Nedir?**
#     * Bugün iş dünyasında veri analizi yoluyla toplanan bu kadar çok bilgi ile, bu verilerin bir resmini çizmenin bir yolunu bulmalıyız, böylece onları yorumlayabiliriz.
#     * Veri görselleştirme, haritalara veya grafiklere görsel bağlam sağlayarak bilginin ne anlama geldiğine dair bize net bir fikir verir.
#     * Bu, verileri insan zihninin anlaması için daha doğal hale getirir ve bu nedenle büyük veri kümelerindeki eğilimleri, modelleri ve aykırı değerleri tanımlamayı kolaylaştırır.
#     * Kısaca, veri görselleştirme verilerin veya bilgilerin bir grafik, çizelge veya diğer görsel formatta temsilidir.
# * **Veri Görselleştirmenin Önemi**
#     * Ana amaç, veri ve istatistikleri görselleştirmek, bilgi edinmek için ekranları yorumlamaktır.
#     * Veri görselleştirme, veri temizleme, veri yapısını keşfetme, aykırı değerleri ve olağan dışı grupları tespit etme, eğilimleri ve kümeleri belirleme, yerel kalıpları belirleme, modelleme çıktısını değerlendirme ve sonuçları sunma için kullanışlıdır.
#     * Makine öğrenimi, tahmine dayalı analiz gibi analizler yapmayı kolaylaştırır ve bu analizler, daha sonra sunum için yararlı görselleştirmeler işlevi görebilir.
#     * Finans, pazarlama, teknoloji, tasarım veya başka herhangi bir alanda çalışıyor olun, verileri görselleştirmeniz gerekir. Bu gerçek, veri görselleştirmenin önemini göstermektedir.
# * **Veri Görselleştirmede En Çok Kullanılan Python Kütüphaneleri**
#     1. **Matplotlib:** Python temellerini hatırlama bölümünde gördüğümüz temel görselleştirme kütüphenesi.
#     1. **Seaborn:** İstatiksel bir Python veri görselleştirme kütüphanesidir. (Bu bölümde göreceğiz)
#     1. **Plotly:** Etkileşimli bir Python veri görselleştirme kütüphanesidir. (Bu bölümde göreceğiz)
# ![image.png](attachment:9f256375-11c3-424e-aa37-3c3c1d5c9d49.png)

# %% [markdown]
# ## Seaborn Kütüphanesi
# * Seaborn, Matplotlib kütüphanesi tabanlı, istatiksel bir Python veri görselleştirme kütüphanesidir.
# * Seaborn kullanıcılara istatiksel görselleştirmeler yapmaları için yüksek seviyeli bir arayüz sunar.
# * Seaborn kütüphanesi’nin işlevleri aşağıdaki gibidir.
#     * Birden çok değişken arasındaki ilişkileri detaylı bir şekilde incelemek adına sunulan veri kümesi tabanlı bir uygulama programlama arayüzüdür.
#     * Kategorik değişkenleri gözlemlemek ve üzerinde istatistiksel işlemler yapmak için destek sağlar.
#     * Karmaşık görselleştirmeler oluşturmayı sağlayan çoklu grafikleri destekler.
#     * Alt kümeler arasında karşılaştırma yapmak için tek değişkenli ve çift değişkenli görselleştirmeler sunar.
#     * Görselleştirmeyi daha anlaşılır hale getiren geniş renk skalası mevcuttur.
# * Seaborn ve Matplotlib kütüphanesi arasındaki farklar
#     * Matplotlib kişiselleştirilebilir fakat plotları daha anlaşılır, göze hitap eden şekle getirmek bir hayli zordur.
#     * Seaborn sahip olduğu renk paleti, arayüzler ve grafik çeşitleri ile kullanıcıya farklı çözümler sunar.
#     * Pandas Kütüphanesi ile çalışırken Seaborn kolaylık sağlar.
# <br><br>**İçerik:**
# 1. [120 Yıllık Olimpiyat Tarihi Veri Seti](#1)
# 1. [Saçılım Grafiği](#2)
# 1. [Saçılım Grafiği - Kategorik](#3)
# 1. [Saçılım Grafiği - Doğrusal Regresyon](#4)
# 1. [Renk Paletleri](#5)
# 1. [Çizgi Grafiği](#6)
# 1. [Çizgi Grafiği - Kategorik](#7)
# 1. [Histogram](#8)
# 1. [Histogram - Kategorik](#9)
# 1. [İki Boyutlu Histogram](#10)
# 1. [Çubuk Grafiği](#11)
# 1. [Kutu Grafiği](#12)
# 1. [Sıcaklık Haritası](#13)
# 1. [Keman Grafiği](#14)
# 1. [Ortaklık Grafiği](#15)
# 1. [Çift/Eş Grafiği](#16)
# 1. [Sayma Grafiği](#17)

# %% [markdown]
# <a id='1'></a>
# ## 120 Yıllık Olimpiyat Tarihi Veri Seti
# * 120 Yıllık Olimpiyat Tarihi veri seti tanıtımını ve temizlenmesini veri bilimi bölümünde yaptığımız için bu bölümde verinin içe aktarılması işlemini yapacağız.

# %%
# buraya kod yazacağız
# kütüphaneleri import edelim
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# phython'daki uyarıları kapatalım
import warnings
warnings.filterwarnings("ignore")

# %%
# buraya kod yazacağız
veri = pd.read_csv('/content/drive/MyDrive/BTK-3-YZ/data/olimpiyatlar_temizlenmis.csv')
veri.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d126f2fd2362> in <cell line: 2>()
#       1 # buraya kod yazacağız
# ----> 2 veri = pd.read_csv('/content/drive/MyDrive/BTK-3-YZ/data/olimpiyatlar_temizlenmis.csv')
#       3 veri.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# <a id='2'></a>
# ## Saçılım Grafiği
# *  Saçılım grafiği, iki farklı değişkenin arasındaki ilişkiyi belirlemek için kullanılır.

# %%
# buraya kod yazacağız
# Saçılım grafiği çizmek için bir plot yapalım
def sacilimGrafik():
    sns.scatterplot(x = 'boy', y = 'kilo', data = veri)
    plt.title('Boy ve Kilo Dağılımı - Beyaz Izgara Tema')
    plt.show()

sacilimGrafik()

# %%
# buraya kod yazacağız
# seaborn stilleri
sns.set_style("white")
sacilimGrafik()

# %%
# buraya kod yazacağız
# seaborn stilleri
sns.set_style("darkgrid")
sacilimGrafik()

# %%
# buraya kod yazacağız
sns.set_style("whitegrid")
sacilimGrafik()

# %% [markdown]
# * Bu grafiklerden boy ve kilo arasında pozitif ilişki olduğu anlamını çıkarabiliriz.

# %% [markdown]
# <a id='3'></a>
# ## Saçılım Grafiği - Kategorik

# %%
# buraya kod yazacağız
# hue = sınıf ya da etiket olarak adlandırılabilir.
# scatter plot çizdirilirken hue'ya göre sınıflar farklı renklendirilir
sns.scatterplot(x='boy', y='kilo', hue='madalya', data = veri[veri['madalya'] == 'gold'])
plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-746533ff2179> in <cell line: 4>()
#       2 # hue = sınıf ya da etiket olarak adlandırılabilir.
#       3 # scatter plot çizdirilirken hue'ya göre sınıflar farklı renklendirilir
# ----> 4 sns.scatterplot(x='boy', y='kilo', hue='madalya', data = veri[veri['madalya'] == 'gold'])
#       5 plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
#       6 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# <a id='4'></a>
# ## Saçılım Grafiği - Doğrusal Regresyon

# %%
# buraya kod yazacağız
# saçılım grafiği çizilir; üzerine doğrusal regresyon yöntemi ile line fit işlemi gerçekleştirilir
# doğrusal regresyon kavramı, makine öğrenmesi konusu içerisinde anlatılacaktır.
sns.regplot(x='boy', y='kilo', data=veri, marker='+', scatter_kws={'alpha':0.2})
plt.title('Boy ve Kilo Dağılımı')
plt.show()
#regresyon çizgisinin rengi

# %% [markdown]
# * Doğrusal regresyon sonucu oluşan, doğrunun eğiminin pozitif olmasından anlaşılacağı üzere boy ve kilo arasında pozitif ilişki vardır.

# %% [markdown]
# <a id='5'></a>
# ## Renk Paletleri
# * Renk paletleri görselleştirmede rengin gücünü kullanmak için belirlenmiş, içerisinde farklı renkleri barındıran yapılardır.

# %%
# buraya kod yazacağız
# Renk Paletleri
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette = 'Set1')
plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
plt.show()

# %%
# buraya kod yazacağız
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette = 'rocket')
plt.title('Madalyaya Göre Boy ve Kilo Dağılımı')
plt.show()

# %% [markdown]
# <a id='6'></a>
# ## Çizgi Grafiği
# * Çizgi grafiği, birbirine bağlanan düz çizgi parçalarının veri noktaları serisinin bilgisini gösteren bir tür çizimdir.
# * Çizelge genellikle belirli bir zaman aralığındaki - zaman serisi - verilerin değerlerini görselleştirmek için kullanılır ve kronolojiksel olarak çizilir.
# * Ayrıca zamana bağlı ölçümlerin görselleştirilmesi için de kullanılır.

# %%
# buraya kod yazacağız
sns.lineplot(x='boy', y='kilo', data = veri)
plt.title('Boy ve Kilo')
plt.show()

# %% [markdown]
# <a id='7'></a>
# ## Çizgi Grafiği - Kategorik

# %%
# buraya kod yazacağız
sns.lineplot(x='boy', y='kilo', hue='cinsiyet', data=veri)
plt.title('Cinsiyete Göre Boy ve Kilo Bağımlılıkları')
plt.show()

# %% [markdown]
# * Bu grafikten anlaşıldığı gibi kadınlar boy ve kiloları erkeklere göre daha az olabiliyor.

# %% [markdown]
# <a id='8'></a>
# ## Histogram
# * Histogram, gruplandırılmış bir veri dağılımının sütun grafiğiyle gösterimidir.
# * Tekrarlı sayılardan oluşan verilerin, uygulanan işlemlerden sonra önce tabloya, tablodan yararlanarak grafiğe aktarılması, yani veri gruplarının grafiğinin dikdörtgen sütunlar halinde gösterilmesidir.

# %%
# buraya kod yazacağız
sns.displot(veri, x = "kilo")
plt.ylabel("Frekans")
plt.title("Kilo Histogram")
plt.show()

# %% [markdown]
# <a id='9'></a>
# ## Histogram - Kategorik

# %%
# buraya kod yazacağız
sns.distplot(veri.kilo, hue = "cinsiyet")
plt.ylabel("Frekans")
plt.title("Cinsiyete Göre Kilo Histogramı")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f065eaaf1333> in <module>
#       1 # buraya kod yazacağız
# ----> 2 sns.distplot(veri.kilo, hue = "cinsiyet")
#       3 plt.ylabel("Frekans")
#       4 plt.title("Cinsiyete Göre Kilo Histogramı")
#       5 plt.show()
#
# TypeError: distplot() got an unexpected keyword argument 'hue'

# %%
# buraya kod yazacağız
sns.displot(veri, x = "kilo", col = "cinsiyet", multiple="dodge")
plt.show()

# %% [markdown]
# * Histogramlardan anlaşılabileceği üzere, kadınların ortalama kilosu, erkeklerin ortalama kilosuna göre daha azdır.

# %% [markdown]
# <a id='10'></a>
# ## İki Boyutlu Histogram

# %%
# buraya kod yazacağız
sns.displot(veri, x="kilo", y="boy", kind="kde")
plt.xlabel("kilo")
plt.ylabel("boy")
plt.title("Kilo - Boy Histogram")
plt.show()

# %%
# buraya kod yazacağız
sns.displot(veri, x="kilo", y="boy", hue="cinsiyet", kind="kde")
plt.xlabel("kilo")
plt.ylabel("boy")
plt.title("Kilo - Boy Histogram")
plt.show()

# %%
# buraya kod yazacağız
sns.displot(veri, x="kilo", y="boy", hue="cinsiyet", fill = True)
plt.xlabel("kilo")
plt.ylabel("boy")
plt.title("Cinsiyete göre Kilo - Boy Histogram")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cb5696fdcf18> in <cell line: 2>()
#       1 # buraya kod yazacağız
# ----> 2 sns.displot(veri, x="kilo", y="boy", hue="cinsiyet", fill = True)
#       3 plt.xlabel("kilo")
#       4 plt.ylabel("boy")
#       5 plt.title("Cinsiyete göre Kilo - Boy Histogram")
#
# NameError: name 'veri' is not defined

# %% [markdown]
# * İki boyutlu histogram, kadınlar ile erkekler arasında boy-kilo ilişkisinin farklılık gösterdiği görülebilir.

# %% [markdown]
# <a id='11'></a>
# ## Çubuk Grafiği
# * Çubuk grafik veya çubuk grafik, kategorik verileri temsil ettikleri değerlerle orantılı yükseklik veya uzunluktaki dikdörtgen çubuklarla sunan bir grafiktir.

# %%
# buraya kod yazacağız
sns.barplot(x="madalya", y="boy", data=veri)
plt.title("Madalyalara göre boy grafikleri")
plt.show()

# %%
# buraya kod yazacağız
sns.barplot(x="madalya", y="boy", data=veri, hue="cinsiyet")
plt.title("Madalyalara göre boy grafikleri")
plt.show()

# %%
# buraya kod yazacağız
sns.catplot(x="madalya", y="yas", hue="cinsiyet", col="sezon",
                 data=veri, kind="bar",height=4, aspect=.7)
plt.show()

# %% [markdown]
# <a id='12'></a>
# ## Kutu Grafiği
# * İstatistik biliminde kutu grafiği bir betimsel istatistik ve istatistiksel grafik aleti olup niceliksel verileri görsel şekilde özetlemek için kutu-ve-bıyıklar grafiği adı altında bir açıklayıcı veri analizi aracı olarak geliştirilmiştir. (Kutu grafiği ile ilgili bilgi veri biliminde verilmiştir.)

# %%
# buraya kod yazacağız
sns.boxplot(x="sezon", y="boy", data=veri)
plt.show()

# %%
# buraya kod yazacağız
sns.boxplot(x="sezon", y="boy", hue="cinsiyet",data=veri, palette="Set2")
plt.show()

# %%
# buraya kod yazacağız
veri_gecici = veri.loc[:,["yas","boy","kilo"]]
sns.boxplot(data=veri_gecici, orient="h", palette="Set2")
plt.show()

# %%
# buraya kod yazacağız
sns.catplot(x="sezon", y="boy",hue="cinsiyet", col="madalya",data=veri, kind="box",height=4, aspect=.7);

# %% [markdown]
# * Farklı madalyalar için, yaz ve kış sezonlarında, erkekler ve kadınlar arasında boy farklılıkları bu grafikten okunabiliyor.

# %% [markdown]
# <a id='13'></a>
# ## Isı Haritası
# * Isı haritası, sayısal özellikler/sütunlar arasındaki ilişkiyi görselleştirmek için kullanılan bir tekniktir.

# %%
# buraya kod yazacağız
sns.heatmap(veri.corr(), annot=True, linewidths=.5, fmt= '.1f')
plt.show()

# %% [markdown]
# * Sayısal özellikler olan boy, kilo yas ve yıllar arasında ilişkiyi incelemek için korelasyon matris kullandık.
# * Daha önceden de bildiğimiz gibi boy ve kilo arasında 0.8 değerinde bir pozitif ilişki mevcuttur.

# %% [markdown]
# <a id='14'></a>
# ## Keman Grafiği
# * Keman grafiği, sayısal verileri çizme yöntemidir.
# * Kutu grafiğine benzer yorumlanır.

# %%
# buraya kod yazacağız
sns.violinplot(x="sezon", y="boy", data=veri)
plt.show()

# %%
# buraya kod yazacağız
sns.violinplot(x="sezon", y="boy", data=veri, hue="cinsiyet")
plt.show()

# %%
# buraya kod yazacağız
sns.violinplot(x="sezon", y="boy", data=veri, hue="cinsiyet", split=True)
plt.show()

# %%
# buraya kod yazacağız
sns.catplot(x="sezon", y="boy",
                hue="cinsiyet", col="madalya",
                data=veri, kind="violin", split=True,
                height=4, aspect=.7)
plt.show()

# %% [markdown]
# <a id='15'></a>
# ## Ortaklık Grafiği
# * Farklı özellikler arasındaki ilişkiyi farklı görselleştirme yöntemleri kullanarak incelemeye yarayan bir grafiktir.

# %%
# buraya kod yazacağız
sns.jointplot(
    data=veri,
    x="kilo", y="boy", hue="sezon",
    kind="kde")
plt.show()

# %%
# buraya kod yazacağız
g = sns.JointGrid(data=veri, x="kilo", y="boy")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %% [markdown]
# <a id='16'></a>
# ## Çift/Eş Grafiği
# * Veri seti içerisinde bulunan sayısal özellikler arasındaki ilişkiyi farklı görselleştirme yöntemleri kullanarak incelemeye yarayan bir grafiktir.

# %%
# buraya kod yazacağız
sns.pairplot(veri)
plt.show()

# %%
# buraya kod yazacağız
g = sns.PairGrid(veri)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %% [markdown]
# <a id='17'></a>
# ## Sayma Grafiği
# * Sayma grafiği, niceliksel değişken yerine kategorik bir histogram olarak düşünülebilir.

# %%
# buraya kod yazacağız
sns.countplot(x="sehir", data=veri)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Olimpiyatlar farklı şehirlerde düzenlenmiştir.
# * Hangi şehirde kaç adet madalya verilmiş olduğunu görebiliriz.

# %% [markdown]
# ## Plotly Kütüphanesi
# * Plotly Python programlama dili ile uyumu çalışan veri görselleştirme ve dashboard oluşturmaya yarayan çeşitli fonksiyonlar içeren etkileşimli bir kütüphanedir.
# * Plotly kullanılarak, interaktif grafikler birden fazla kişiyle çevrimiçi olarak kolayca paylaşılabilir.
# * Plotly, verileri yükleyerek ve grafiksel kullanıcı arayüzü kullanarak etkileşimli grafikler oluşturmak için teknik geçmişi olmayan kişiler tarafından da kullanılabilir.
# * Plotly ile etkileşimli grafikler oluşturmak için sözdizimi ilerleyen derslerde göreceğimiz gibi oldukça basittir.
# <br><br>**İçerik:**
# 1. [Dünya Üniversite Sıralaması Veri Seti](#30)
# 1. [Çizgi Grafiği](#31)
# 1. [Saçılım Grafiği](#32)
# 1. [Çubuk Grafiği](#33)
# 1. [Dairesel Grafik](#34)
# 1. [Kabarcık Grafiği](#35)
# 1. [Histogram](#36)
# 1. [Kutu Grafiği](#37)
# 1. [Saçılım Matrisi Grafiği](#38)
# 1. [Alt Plan Grafiği](#39)
# 1. [3 Boyutlu Saçılım Grafiği](#40)
# 1. [Dünya Haritası Grafiği](#41)

# %% [markdown]
# <a id='30'></a>
# ## Dünya Üniversite Sıralaması Veri Seti
# * Bu bölümde dünyada bulunan üniversitelerin farklı kriterlere göre sıralamasını içeren bir veri seti üzerine çalışacağız.
# * Veri seti içerisinde bulunan sütunların isimleri ve açıklamaları
#     1. world_rank - dünya sıralaması
#     1. university_name - üniversite ismi
#     1. country - üniversitenin bulunduğu ülke
#     1. teaching - öğretim puanı
#     1. international - uluslararası öğrenci/çalışan açısından üniversite puanı
#     1. research - araştırma puanı
#     1. citations - alıntı puanı
#     1. income - gelir puanı
#     1. total_score - toplam puan
#     1. num_students - öğrenci sayısı
#     1. student_staff_ratio -  öğrenci/çalışan oranı
#     1. international_students - uluslararası öğrenci oranı
#     1. female_male_ratio - kadın/erkek öğrenci oranı
#     1. year - sıralamanın yapıldığı yıl

# %%
# buraya kod yazacağız
# kütüphaneleri import edelim
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#python'da uyarıları kapatalım
import warnings
warnings.filterwarnings("ignore")

#plotly
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.io as pio
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# buraya kod yazacağız
veri = pd.read_csv("universite_siralamasi.csv")
veri.head(3)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20,152                  8.9                    25%               NaN
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
#
#    year
# 0  2011
# 1  2011
# 2  2011

# %%
# buraya kod yazacağız
veri.columns
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year'],
#       dtype='object')

# %%
# buraya kod yazacağız
veri.rename(columns={'world_rank'                        : 'dunya_siralama',
                     'university_name'                   : 'uni_isim',
                     'country'                           : 'ulke',
                     'teaching'                          : 'ogretim',
                     'international'                     : 'uluslararasi',
                     'research'                          : 'arastirma',
                     'citations'                         : 'alinti',
                     'income'                            : 'gelir',
                     'total_score'                       : 'toplam_puan',
                     'num_students'                      : 'ogrenci_sayisi',
                     'student_staff_ratio'               : 'ogrenci_calisan_orani',
                     'international_students'            : 'uluslararasi_ogrenci',
                     'female_male_ratio'                 : 'kadin_erkek_orani',
                     'year'                              : 'yil'}, inplace=True) # inplace = True dediğimiz zaman ismi değiştirilen veri otomatik olarak veri isimli değişkene kaydedilir.
veri.head(2)
# Out:
#   dunya_siralama                            uni_isim  \
# 0              1                  Harvard University
# 1              2  California Institute of Technology
#
#                        ulke  ogretim uluslararasi  arastirma  alinti gelir  \
# 0  United States of America     99.7         72.4       98.7    98.8  34.5
# 1  United States of America     97.7         54.6       98.0    99.9  83.7
#
#   toplam_puan ogrenci_sayisi  ogrenci_calisan_orani uluslararasi_ogrenci  \
# 0        96.1         20,152                    8.9                  25%
# 1        96.0          2,243                    6.9                  27%
#
#   kadin_erkek_orani   yil
# 0               NaN  2011
# 1           33 : 67  2011

# %% [markdown]
# <a id='31'></a>
# ## Çizgi Grafiği
# * Çizgi grafiği, birbirine bağlanan düz çizgi parçalarının veri noktaları serisinin bilgisini gösteren bir tür çizimdir.
# * Çizelge genellikle belirli bir zaman aralığındaki - zaman serisi - verilerin değerlerini görselleştirmek için kullanılır ve kronolojiksel olarak çizilir.
# * Ayrıca zamana bağlı ölçümlerin görselleştirilmesi için de kullanılır.

# %%
# buraya kod yazacağız
# ilk 100 örneği al
df = veri.iloc[:100,:]
df.head(3)
# Out:
#   dunya_siralama                               uni_isim  \
# 0              1                     Harvard University
# 1              2     California Institute of Technology
# 2              3  Massachusetts Institute of Technology
#
#                        ulke  ogretim uluslararasi  arastirma  alinti gelir  \
# 0  United States of America     99.7         72.4       98.7    98.8  34.5
# 1  United States of America     97.7         54.6       98.0    99.9  83.7
# 2  United States of America     97.8         82.3       91.4    99.9  87.5
#
#   toplam_puan ogrenci_sayisi  ogrenci_calisan_orani uluslararasi_ogrenci  \
# 0        96.1         20,152                    8.9                  25%
# 1        96.0          2,243                    6.9                  27%
# 2        95.6         11,074                    9.0                  33%
#
#   kadin_erkek_orani   yil
# 0               NaN  2011
# 1           33 : 67  2011
# 2           37 : 63  2011

# %%
# buraya kod yazacağız
# plotly stilleri
pio.templates.default = "simple_white" # grafik stilini beyaz yap

# %%
# buraya kod yazacağız
# ilk grafik
cizgi1 = go.Scatter(x = df.dunya_siralama,   # x ekseninde dünya sıralaması olsun
                    y = df.alinti,           # y ekseninde alıntı olsun
                    mode = "lines+markers",  # grafik çizgi ve saçılım olsun
                    name = "Alıntı",         # etiketi alıntı olsun
                    marker = dict(color = 'rgba(78, 78, 250, 0.85)'), # renk
                    text = df.uni_isim)      # grafik üzerinde imleç ilgili noktaya gelince, üniversite ismi yazsın

# ikinci grafik
cizgi2 = go.Scatter(x = df.dunya_siralama,   # x ekseninde dünya sıralaması olsun
                    y = df.ogretim,           # y ekseninde eğitim-öğretim faaliyetlerinden alınan puan olsun
                    mode = "lines+markers",  # grafik çizgi ve saçılım olsun
                    name = "Öğretim",         # etiketi alıntı olsun
                    marker = dict(color = 'rgba(202, 43, 15, 0.85)'), # renk
                    text = df.uni_isim)      # grafik üzerinde imleç ilgili noktaya gelince, üniversite ismi yazsın
veri_ = [cizgi1, cizgi2]   # 2 grafiği veri_ değişkeni içerisine koy

#başlık ekle ve eksen ayarlarını yap
yerlesim = dict(title = 'Dünya Sıralamasında İlk 100 Üniversitenin Alıntı ve Öğretim Puanları',
             xaxis = dict(title = 'Dünya Sıralaması', ticklen=5, zeroline = False))
fig = dict(data = veri_, layout = yerlesim) # figür oluştur
plot(fig, filename = '1_çizgi-alıntı ve öğretim puanları.html') # .html olarak kaydet
# Out:
# '1_çizgi-alıntı ve öğretim puanları.html'

# %% [markdown]
# ### Plotly Grafik Kullanımı ve Özellikleri
# ![image.png](attachment:e5c8a4fe-20e7-4bfb-a286-173903c2dd91.png)

# %% [markdown]
# <a id='32'></a>
# ## Saçılım Grafiği
# *  Saçılım grafiği, iki farklı değişkenin arasındaki ilişkiyi belirlemek için kullanılır.

# %%
# buraya kod yazacağız
# 2014, 2015 ve 2016 yıllarını ayıralım ve ilk 100'er örneği alalım
veri2014 = veri[veri.yil == 2014].iloc[:100, :]
veri2015 = veri[veri.yil == 2015].iloc[:100, :]
veri2016 = veri[veri.yil == 2016].iloc[:100, :]

# ilk grafik
cizgi1 = go.Scatter(x = veri2014.dunya_siralama,   # x ekseninde dünya sıralaması olsun
                    y = veri2014.alinti,           # y ekseninde alıntı olsun
                    mode = "markers",              # grafik saçılım olsun
                    name = "2014",                 # etiketi 2014 olsun
                    marker = dict(color = 'rgba(2, 255, 15, 0.8)'), # renk
                    text = veri2014.uni_isim)      # grafik üzerinde imleç ilgili noktaya gelince, üniversite ismi yazsın

# ikinci grafik
cizgi2 = go.Scatter(x = veri2015.dunya_siralama,   # x ekseninde dünya sıralaması olsun
                    y = veri2015.alinti,           # y ekseninde alıntı olsun
                    mode = "markers",              # grafik saçılım olsun
                    name = "2015",                 # etiketi 2015 olsun
                    marker = dict(color = 'rgba(255, 0, 123, 0.8)'), # renk
                    text = veri2015.uni_isim)      # grafik üzerinde imleç ilgili noktaya gelince, üniversite ismi yazsın

# üçüncü grafik
cizgi3 = go.Scatter(x = veri2016.dunya_siralama,   # x ekseninde dünya sıralaması olsun
                    y = veri2016.alinti,           # y ekseninde alıntı olsun
                    mode = "markers",              # grafik saçılım olsun
                    name = "2016",                 # etiketi 2016 olsun
                    marker = dict(color = 'rgba(0, 5, 200, 0.8)'), # renk
                    text = veri2016.uni_isim)      # grafik üzerinde imleç ilgili noktaya gelince, üniversite ismi yazsın

veri_ = [cizgi1, cizgi2, cizgi3]   # 3 grafiği veri_ değişkeni içerisine koy

#başlık ekle ve eksen ayarlarını yap
yerlesim = dict(title = '2014, 2015 ve 2016 yıllarında ilk 100 Üniversitenin Alıntı ve Dünya Sıralaması',
             xaxis = dict(title = 'Dünya Sıralaması', ticklen=5, zeroline = False),
             yaxis = dict(title = 'Alıntı', ticklen = 5, zeroline = False)  )

fig = dict(data = veri_, layout = yerlesim) # figür oluştur
plot(fig, filename = '2_saçılım-alıntı ve dünya sıralamsı.html') # .html olarak kaydet
# Out:
# '2_saçılım-alıntı ve dünya sıralamsı.html'

# %% [markdown]
# <a id='33'></a>
# ## Çubuk Grafiği
# * Çubuk grafik veya çubuk grafiği, kategorik verileri temsil ettikleri değerlerle orantılı yükseklik veya uzunluktaki dikdörtgen çubuklarla sunan bir grafiktir.

# %%
# buraya kod yazacağız
# 2014 yılının ilk 5 üniversitesini alalım
veri2014 = veri[veri.yil == 2014].iloc[:5, :]

#ilk grafik
cizgi1 = go.Bar(x= veri2014.uni_isim,
                y= veri2014.alinti,
                name = "Alıntı",
                marker = dict(color= 'rgba(255, 127, 39, 0.5)', # çubuk rengi
                              line= dict(color='rgb(0,0,0)', width=1.5)), # çubuk etrafındaki çizgilerin rengi ve kalınlığı
                text = veri2014.ulke)

#ikinci grafik
cizgi2 = go.Bar(x= veri2014.uni_isim,
                y= veri2014.ogretim,
                name = "Öğretim",
                marker = dict(color= 'rgba(64, 0, 128, 0.5)', # çubuk rengi
                              line= dict(color='rgb(0,0,0)', width=1.5)), # çubuk etrafındaki çizgilerin rengi ve kalınlığı
                text = veri2014.ulke)

veri_ = [cizgi1, cizgi2]
yerlesim = go.Layout(barmode = "group")
fig = go.Figure(data = veri_, layout = yerlesim)
plot(fig, filename = '3_çubuk-alıntı ve öğretim puanı.html') # html formatında kaydet
# Out:
# '3_çubuk-alıntı ve öğretim puanı.html'

# %% [markdown]
# <a id='34'></a>
# ## Dairesel Grafik
# * Dairesel grafik, istatistik biliminde betimsel istatistik alanında kategorik verileri görsel bir şekilde betimleyip özetlemek için hazırlanan; içindeki kategori dilimlerini orantısal olarak gösteren bir daire şeklinde sunulan bir gösterim aracıdır.

# %%
# buraya kod yazacağız
# 2016 yılının ilk 8 üniversitesini alalım
veri2016 = veri[veri.yil == 2016].iloc[:8, :]
dilim1 = veri2016.ogrenci_sayisi
dilim1_liste = [float(each.replace(',' , '.')) for each in veri2016.ogrenci_sayisi] # str(2,4) -> str(2.4) -> float(2.4) = 2.4
etiketler = veri2016.uni_isim

# ilk grafik
cizgi = go.Pie(labels = etiketler,
               values = dilim1_liste,
               hoverinfo = 'label+value+percent',
               textinfo = 'value+percent',
               textfont = dict(size=8),
               rotation = 180,
               hole = 0.3,
               marker = dict(line=dict(color='#000000', width=1)))

veri_ = [cizgi]
yerlesim = dict(title = "2016 yılında dünya sıralamasında ilk 8'de bulunan üniversitelerin öğrenci sayıları ve oranları",
               legend=dict(orientation="h"))

fig = dict(data=veri_, layout = yerlesim)
plot(fig, filename = '4_dairesel-öğrenci sayısı.html') # .html formatında kaydet
# Out:
# '4_dairesel-öğrenci sayısı.html'

# %% [markdown]
# <a id='35'></a>
# ## Kabarcık Grafiği
# * Saçılım grafiği olarak da adlandırılabilir.
# * Saçılım noktalarına verilen renk ve büyüklük özellikleri sayesinde görselleştirmeye yeni boyutlar katar.

# %%
# buraya kod yazacağız
# 2016 yılının ilk 20 üniversitesini alalım
veri2016 = veri[veri.yil == 2016].iloc[:20,:]
ogrenci_sayisi = [float(each.replace(',','.')) for each in veri2016.ogrenci_sayisi]
uluslararasi_renk = [float(each) for each in veri2016.uluslararasi]

data = [{'y': veri2016.ogretim,
         'x': veri2016.dunya_siralama,
         'mode': 'markers',
         'marker': { 'color': uluslararasi_renk,
                     'size': ogrenci_sayisi,
                     'showscale': True},
         "text"  : veri2016.uni_isim}]

plot(data, filename = '5_kabarcik-öğrenci sayısı.html') # html formatında kaydet
# Out:
# '5_kabarcik-öğrenci sayısı.html'

# %% [markdown]
# <a id='36'></a>
# ## Histogram
# * Histogram, gruplandırılmış bir veri dağılımının sütun grafiğiyle gösterimidir.
# * Tekrarlı sayılardan oluşan verilerin, uygulanan işlemlerden sonra önce tabloya, tablodan yararlanarak grafiğe aktarılması, yani veri gruplarının grafiğinin dikdörtgen sütunlar halinde gösterilmesidir.

# %%
# buraya kod yazacağız
# 2011 ve 2012 yıllarında öğrenci ve çalışan oranlarını alalım
veri2011 = veri.ogrenci_calisan_orani[veri.yil == 2011]
veri2012 = veri.ogrenci_calisan_orani[veri.yil == 2012]

# %%
# ilk grafik
cizgi1 = go.Histogram(x = veri2011,
                      opacity = 0.75,
                      name = "2011",
                      marker = dict(color='rgba(171, 50, 144, 0.6)'))

# ikinci grafik
cizgi2 = go.Histogram(x = veri2012,
                      opacity = 0.75,
                      name = "2012",
                      marker = dict(color='rgba(23, 150, 196, 0.6)'))

veri_ = [cizgi1, cizgi2]

yerlesim = go.Layout(barmode = 'overlay',
                     title = '2011 ve 2012 yıllarında öğrenci/çalışan oranı',
                     xaxis = dict(title='Öğrenci-Çalışan Oranı'),
                     yaxis = dict(title='Frekans'))

fig = go.Figure(data = veri_, layout = yerlesim)
plot(fig, filename = '6_histogram-öğrenci çalışan oranı.html') # html formatında kaydet
# Out:
# '6_histogram-öğrenci çalışan oranı.html'

# %% [markdown]
# <a id='37'></a>
# ## Kutu Grafiği
# * İstatistik biliminde kutu grafiği bir betimsel istatistik ve istatistiksel grafik aleti olup niceliksel verileri görsel şekilde özetlemek için kutu-ve-bıyıklar grafiği adı altında bir açıklayıcı veri analizi aracı olarak geliştirilmiştir. (Kutu grafiği ile ilgili bilgi veri biliminde verilmiştir.)

# %%
# buraya kod yazacağız
# 2015 yılının verisini alalım
veri2015 = veri[veri.yil == 2015]

# ilk grafik
cizgi1 = go.Box(y = veri2015.toplam_puan,
                name = '2015 yılında Toplam Puan',
                marker = dict(color = 'rgb(255, 86, 4)'))

# ikinci grafik
cizgi2 = go.Box(y = veri2015.arastirma,
                name = '2015 yılında Araştırma Puanı',
                marker = dict(color = 'rgb(14, 149, 233)'))

veri_ = [cizgi1, cizgi2]
plot(veri_, filename = '7_kutu-toplam ve araştırma puanı.html')
# Out:
# '7_kutu-toplam ve araştırma puanı.html'

# %% [markdown]
# <a id='38'></a>
# ## Saçılım Matrisi Grafiği
# * Saçılım yöntemi kullanılarak, birden fazla özelliğin tek bir görsel üzerinde farklı görselleştirme teknikleri kullanılarak karşılaştırmasına olanak sağlar.

# %%
# buraya kod yazacağız
# 2015 yılının verisini alalım
veri_gecici = veri[veri.yil == 2015]

veri2015 = veri_gecici.loc[:,["arastirma", "uluslararasi", "toplam_puan"]]
veri2015["index"] = np.arange(1,len(veri2015)+1)

# scatter matrix
fig = ff.create_scatterplotmatrix(veri2015, diag='box', index='index',
                                  colormap='Jet', colormap_type='cat', height=700, width=700)

"""
Örnek renk haritaları:
'Greys', 'YlGnBu', 'Greens', 'YlOrRd', 'Bluered',
'RdBu', 'Reds', 'Blues', 'Picnic', 'Rainbow',
'Portland', 'Jet', 'Hot', 'Blackbody', 'Earth',
'Electric', 'Viridis', 'Cividis']
"""
plot(fig, filename = '8_saçılım matrisi - araştırma uluslararası ve toplam puan.html')
# Out:
# '8_saçılım matrisi - araştırma uluslararası ve toplam puan.html'

# %% [markdown]
# <a id='39'></a>
# ## Alt Plan Grafiği
# * Tek bir figür içerisinde bulunan farklı grafiklerin bir araya gelmesi ile oluşur.

# %%
# buraya kod yazacağız
# 2015 yılının verisini alalım
veri2015 = veri[veri.yil == 2015]

# ilk grafik
cizgi1 = go.Scatter(x = veri2015.dunya_siralama,
                    y = veri2015.arastirma,
                    name = "Araştırma - Dünya Sıralaması")

# ikinci grafik
cizgi2 = go.Scatter(x = veri2015.dunya_siralama,
                    y = veri2015.alinti,
                    xaxis = 'x2',
                    yaxis = 'y2',
                    name = "Alıntı - Dünya Sıralaması")

# üçüncü grafik
cizgi3 = go.Scatter(x = veri2015.dunya_siralama,
                    y = veri2015.gelir,
                    xaxis = 'x3',
                    yaxis = 'y3',
                    name = "Gelir - Dünya Sıralaması")

# dördüncü grafik
cizgi4 = go.Scatter(x = veri2015.dunya_siralama,
                    y = veri2015.toplam_puan,
                    xaxis = 'x4',
                    yaxis = 'y4',
                    name = "Toplam Puan - Dünya Sıralaması")

veri_ = [cizgi1, cizgi2, cizgi3, cizgi4]

yerlesim = go.Layout( xaxis = dict(domain=[0, 0.45]),
                      yaxis = dict(domain=[0, 0.45]),
                      xaxis2 = dict(domain=[0.55, 1]),
                      xaxis3 = dict(domain=[0, 0.45],anchor='y3'),
                      xaxis4 = dict(domain=[0.55, 1],anchor='y4'),
                      yaxis2 = dict(domain=[0, 0.45],anchor='x2'),
                      yaxis3 = dict(domain=[0.55, 1],anchor='x3'),
                      yaxis4 = dict(domain=[0.55, 1],anchor='x4'),
                      title = 'Üniversite Sıralamalarına Göre Araştırma, Alıntı, Gelir ve Toplam Puan Değerleri')

fig = go.Figure(data = veri_ , layout = yerlesim)
plot(fig, filename = '9_altplan-araştırma alıntı gelir ve toplam puan.html')
# Out:
# '9_altplan-araştırma alıntı gelir ve toplam puan.html'

# %% [markdown]
# <a id='40'></a>
# ## 3 Boyutlu Saçılım Grafiği
# * 3 Boyutlu saçılım grafiği, verinin farklı özelliklerinin 3 boyutlu ortamda incelenmesini sağlar.

# %%
# buraya kod yazacağız
# 2015 yılının verisini alalım

veri2015 = veri[veri.yil == 2015]

cizgi1 = go.Scatter3d( x= veri2015.dunya_siralama,
                       y= veri2015.arastirma,
                       z= veri2015.alinti,
                       mode = 'markers',
                       marker = dict(size=10, color="seagreen"), opacity = 0.5)

veri_ = [cizgi1]
yerlesim = go.Layout(margin=dict(l=0, r=0, b=0, t=0))

fig = go.Figure(data = veri_, layout = yerlesim)
plot(fig, filename = '10_3B-dünya sıralaması, araştırma ve alıntı.html')
# Out:
# '10_3B-dünya sıralaması, araştırma ve alıntı.html'

# %% [markdown]
# <a id='41'></a>
# ## Dünya Haritası Grafiği
# * Dünya haritası grafiği ile, veri içerisinde bulunan ülke-kıta gibi özelliklerin ve bu özelliklere karşılık gelen sayısal verinin görselleştirilmesi sağlanır.
# * Dünya haritası üzerinde görselleştirme yapılırken, aşağıda bulunan paletlerden biri seçilebilir.
# ![image.png](attachment:5b34e6b5-bca2-4506-b6f4-8cd983b37ccf.png)

# %%
# buraya kod yazacağız
# 2016 yılının verisini alalım

veri2016 = veri[veri.yil == 2016]
veri2016.ulke.value_counts()
# Out:
# United States of America    146
# United Kingdom               77
# Japan                        41
# Germany                      37
# China                        37
#                            ...
# Bangladesh                    1
# Uganda                        1
# Kenya                         1
# Argentina                     1
# Lebanon                       1
# Name: ulke, Length: 72, dtype: int64

# %%
# buraya kod yazacağız
# Listede ABD'den 146 adet okul olduğu için toplamı 146'ya bölüyoruz; görselleştirme daha güzel görünsün diye
ulkeye_gore_toplam_veriler = veri2016.groupby("ulke").sum()/146
ulkeye_gore_toplam_veriler
# Out:
#                              ogretim  arastirma     alinti  \
# ulke
# Argentina                   0.109589   0.061644   0.085616
# Australia                   6.106849   6.971233  12.867808
# Austria                     1.336986   1.095205   2.961644
# Bangladesh                  0.148630   0.049315   0.065753
# Belarus                     0.138356   0.059589   0.041096
# ...                              ...        ...        ...
# Unisted States of America   0.219178   0.243151   0.463699
# United Arab Emirates        0.213699   0.173973   0.239726
# United Kingdom             17.059589  16.370548  32.118493
# United States of America   40.959589  37.350685  70.697260
# Unted Kingdom               0.126027   0.139726   0.355479
#
#                            ogrenci_calisan_orani          yil
# ulke
# Argentina                               0.260959    13.808219
# Australia                               5.715753   428.054795
# ...

# %%
# buraya kod yazacağız
# ilk grafik
cizgi1 = go.Choropleth(locations = ulkeye_gore_toplam_veriler.index,
                       locationmode = 'country names',
                       z = ulkeye_gore_toplam_veriler['arastirma'],
                       text = ulkeye_gore_toplam_veriler.index,
                       autocolorscale = False,
                       reversescale = True,
                       colorscale = "iceFire",
                       marker = dict(line = dict(color = 'rgb(255,255,255)', width = 1)),
                                     colorbar = dict(title = 'Araştırma Puanı', tickprefix = ''))

veri_ = [cizgi1]
yerlesim = go.Layout( title = "Ülkelerin Toplama Araştırma Puanları",
                      geo = dict (showframe = True,
                                  showlakes = False,
                                  showcoastlines = True,
                                  projection = dict( type = 'natural earth')))

fig = dict (data = veri_, layout = yerlesim)
plot(fig, filename = '11_dünya haritası - araştırma puanı.html')
# Out:
# '11_dünya haritası - araştırma puanı.html'

# %% [markdown]
# # Sonuç
# ![image.png](attachment:d45e1b45-7595-4b1a-8079-dff94b5a87c8.png)
